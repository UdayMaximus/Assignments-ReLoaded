# %%
import torch.nn as nn
import torch
import pandas as pd
import numpy as np
import torch.optim as optim

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
path_to_data='data/aksharantar_sampled/'
lang='tel'
startChar='^'
endChar='$'
unknownChar='*'
paddingChar='<pad>'
maxLatinStringLength=30
maxTeluguStringLength=30
trainBatchSize=64
validBatchSize=64
testBatchSize=64

# %%
def load_data():
  train_df=pd.read_csv('tel_train.csv',header=None)
  valid_df=pd.read_csv('tel_valid.csv',header=None)
  test_df=pd.read_csv('tel_test.csv',header=None)
  return train_df,valid_df,test_df

# %%
def add_start_end_chars(df,startChar,endChar):
  df[0]=df[0].apply(lambda x:x+endChar)
  df[1]=df[1].apply(lambda x:startChar+x+endChar)
  return df

# %%
def extract_chars_from_vocabulary(df):
  charSetX=set()
  charSetY=set()
  for i in range(len(df)):
    charSetX.update(set(df[0][i]))
    charSetY.update(set(df[1][i]))
  return charSetX,charSetY

# %%
def map_characters(charSetX,charSetY,paddingChar):
  charDictX={}
  charDictY={}
  for eleNoX,char in enumerate(charSetX):
    charDictX.update({char:eleNoX})
  charDictX.update({paddingChar:eleNoX+1})
  for eleNoY,char in enumerate(charSetY):
    charDictY.update({char:eleNoY})
  charDictY.update({paddingChar:eleNoY+1})
  return charDictX,charDictY

# %%
def inverse_map_characters(charSetX,charSetY,paddingChar):
  charInvDictX={}
  charInvDictY={}
  for eleNoX,char in enumerate(charSetX):
    charInvDictX.update({eleNoX:char})
  charInvDictX.update({eleNoX+1:paddingChar})
  for eleNoY,char in enumerate(charSetY):
    charInvDictY.update({eleNoY:char})
  charInvDictY.update({eleNoY+1:paddingChar})
  return charInvDictX,charInvDictY

# %%
def vectorize(df,charDictX,charDictY,maxLatinStringLength,maxTeluguStringLength,paddingChar):
  # source - latin
  source_index=[]
  for word in df[0]:
    word_index=[]
    for char in word:
      word_index.append(charDictX[char])
    if len(word_index)<maxLatinStringLength:
      word_index=word_index+(maxLatinStringLength-len(word_index))*[charDictX[paddingChar]]
    source_index.append(torch.Tensor(word_index).type(torch.int32))

  # target - telugu
  target_index=[]
  for word in df[1]:
    word_index=[]
    for char in word:
      word_index.append(charDictY[char])
    if len(word_index)<maxTeluguStringLength:
      word_index=word_index+(maxTeluguStringLength-len(word_index))*[charDictY[paddingChar]]
    target_index.append(torch.Tensor(word_index).type(torch.int32))

  # return torch.tensor(source_index).to(device).T,torch.tensor(target_index).to(device).T
  return source_index,target_index

# %%
def vectorizeWithoutPadding(df,charDictX,charDictY,maxLatinStringLength,maxTeluguStringLength,paddingChar):
  # source - latin
  source_index=[]
  for word in df[0]:
    word_index=[]
    for char in word:
      word_index.append(charDictX[char])
    # if len(word_index)<maxLatinStringLength:
    #   word_index=word_index+(maxLatinStringLength-len(word_index))*[charDictX[paddingChar]]
    source_index.append(torch.Tensor(word_index).type(torch.int32))

  # target - telugu
  target_index=[]
  for word in df[1]:
    word_index=[]
    for char in word:
      word_index.append(charDictY[char])
    if len(word_index)<maxTeluguStringLength:
      word_index=word_index+(maxTeluguStringLength-len(word_index))*[charDictY[paddingChar]]
    target_index.append(torch.Tensor(word_index).type(torch.int32))

  # return torch.tensor(source_index).to(device).T,torch.tensor(target_index).to(device).T
  return source_index,target_index

# %%
class myDataset(torch.utils.data.Dataset):
  def __init__(self,XIndices,YIndices):
    self.XIndices=XIndices
    self.YIndices=YIndices
  def __getitem__(self,index):
    return self.XIndices[index], self.YIndices[index]
  def __len__(self):
    return len(self.XIndices)

# %%
train_df,valid_df,test_df = load_data()
test_df_disp=test_df.copy()

# %%
train_df=add_start_end_chars(train_df,startChar,endChar)
valid_df=add_start_end_chars(valid_df,startChar,endChar)
test_df=add_start_end_chars(test_df,startChar,endChar)

# %%
charSetX,charSetY=extract_chars_from_vocabulary(train_df)
charDictX,charDictY = map_characters(charSetX,charSetY,paddingChar)

# %%
charInvDictX,charInvDictY = inverse_map_characters(charSetX,charSetY,paddingChar)

# %%
trainXIndex,trainYIndex=vectorize(train_df,charDictX,charDictY,maxLatinStringLength, maxTeluguStringLength, paddingChar)
trainXIndexNoPadX,trainYIndexNoPadX = vectorizeWithoutPadding(train_df,charDictX,charDictY,maxLatinStringLength, maxTeluguStringLength, paddingChar)
validXIndex,validYIndex=vectorize(valid_df,charDictX,charDictY,maxLatinStringLength, maxTeluguStringLength, paddingChar)
testXIndex,testYIndex=vectorize(test_df,charDictX,charDictY,maxLatinStringLength, maxTeluguStringLength, paddingChar)

# %%
trainDS=myDataset(trainXIndex,trainYIndex)
trainDSNoPadX=myDataset(trainXIndexNoPadX,trainYIndexNoPadX)
validDS=myDataset(validXIndex,validYIndex)
testDS=myDataset(testXIndex,testYIndex)

# %%
trainDL=torch.utils.data.DataLoader(trainDS, batch_size=trainBatchSize,shuffle=True)
trainDLNoPadX=torch.utils.data.DataLoader(trainDSNoPadX, batch_size=trainBatchSize,shuffle=True)
validDL=torch.utils.data.DataLoader(validDS, batch_size=validBatchSize,shuffle=False)
testDL=torch.utils.data.DataLoader(testDS, batch_size=testBatchSize,shuffle=False)

# %%
embeddingDimLatin=128
embeddingDimTelugu=128
hiddenSize=256

vocabSizeLatin=len(charDictX)
vocabSizeTelugu=len(charDictY)
noRecurrentLayers=3
dropOut=0
LatinEmbeddingFun = nn.Embedding(vocabSizeLatin,embeddingDimLatin)
TeluguEmbeddingFun = nn.Embedding(vocabSizeTelugu,embeddingDimTelugu)

myConfig={'encoderType':'LSTM',
    'decoderType':'LSTM',
    'inputSizeEnc':embeddingDimLatin,
    'inputSizeDec':embeddingDimTelugu,
    'hiddenSize':hiddenSize,
    'noRecurrentLayers':noRecurrentLayers,
    'dropOut': dropOut,
    'batchFirst': True,
    'biDirectional':True,
    'LatinEmbeddingFun' : LatinEmbeddingFun,
    'TeluguEmbeddingFun': TeluguEmbeddingFun,
    'LatinVocabSize':vocabSizeLatin,
    'TeluguVocabSize':vocabSizeTelugu,
    }

# %%
class moduleEncoder(nn.Module):
  def __init__(self, config):
    super().__init__()
    self.encoderType=config['encoderType']
    if self.encoderType=='RNN':
      self.calcState=nn.RNN(input_size=config['inputSizeEnc'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])
    elif self.encoderType=='LSTM':
      self.calcState=nn.LSTM(input_size=config['inputSizeEnc'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])
    elif self.encoderType=='GRU':
      self.calcState=nn.GRU(input_size=config['inputSizeEnc'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])
    else:
      self.calcState=nn.RNN(input_size=config['inputSizeEnc'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])

  def forward(self,inputSeqEmbedded,h0=None,c0=None):
    # print(inputSeqEmbedded.size())
    if self.encoderType=='LSTM':
      if (c0 is None) or (h0 is None):
        outputSeq,(hn,cn)=self.calcState(inputSeqEmbedded)
      else:
        outputSeq,(hn,cn)=self.calcState(inputSeqEmbedded,(h0,c0))
    else:#LSTM or GRU
      if h0 is None:
        outputSeq,hn=self.calcState(inputSeqEmbedded)
      else:
        outputSeq,hn=self.calcState(inputSeqEmbedded,h0)
      cn=None
    return outputSeq,(hn,cn)

# %%
class moduleDecoder(nn.Module):
  def __init__(self, config):
    super().__init__()
    self.decoderType=config['decoderType']

    if self.decoderType=='RNN':
      self.calcState=nn.RNN(input_size=config['inputSizeDec'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])
    elif self.decoderType=='LSTM':
      self.calcState=nn.LSTM(input_size=config['inputSizeDec'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])
    elif self.decoderType=='GRU':
      self.calcState=nn.GRU(input_size=config['inputSizeDec'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])
    else:
      self.calcState=nn.RNN(input_size=config['inputSizeDec'], hidden_size=config['hiddenSize'],num_layers=config['noRecurrentLayers'],batch_first=config['batchFirst'],dropout=config['dropOut'],bidirectional=config['biDirectional'])

    if config['biDirectional']:
      self.outputLayer=nn.Linear(2*config['hiddenSize'],config['TeluguVocabSize'])
    else:
      self.outputLayer=nn.Linear(config['hiddenSize'],config['TeluguVocabSize'])

  def forward(self,inputSeq,s0=None,c0=None):
    if self.decoderType=='LSTM':
      if (c0 is None) or (s0 is None):
        outputSeq,(sn,cn)=self.calcState(inputSeq)
      else:
        outputSeq,(sn,cn)=self.calcState(inputSeq,(s0,c0))
    else: #RNN or GRU
      if s0 is None:
        outputSeq,sn=self.calcState(inputSeq)
      else:
        outputSeq,sn=self.calcState(inputSeq,s0)
      cn=None
    return outputSeq,(sn,cn)

# %%
class EncDecModel(nn.Module):
  def __init__(self, config):
    super().__init__()
    self.encoderModule=moduleEncoder(config)
    self.decoderModule=moduleDecoder(config)
    self.hiddenSize=config['hiddenSize']
    self.LatinEmbedding=config['LatinEmbeddingFun'] # input
    self.TeluguEmbedding=config['TeluguEmbeddingFun'] # output

  def forward(self, inputSeq, targetSeq,h0=None,c0=None):

    if targetSeq.dim()==1:
      batchIP=False
      decoderIP = self.TeluguEmbedding(targetSeq[0].view(1))
      # h0=torch.rand(1,self.hiddenSize)
    else:
      batchIP=True
      batchSize,_=targetSeq.size()
      decoderIP = self.TeluguEmbedding(targetSeq[:,0].view(-1,1))
      # h0=torch.rand(1,batchSize,self.hiddenSize)

    inputSeqEmbedded=self.LatinEmbedding(inputSeq)
    # _,(hn,cn)=self.encoderModule(inputSeqEmbedded,h0,c0)
    _,(hn,cn)=self.encoderModule(inputSeqEmbedded)
    # return hn,cn

    sprev=hn
    cprev=cn

    outputSeq=[]
    for i in range(1,targetSeq.size(-1)):
      statePred,(scurr,ccurr) = self.decoderModule(decoderIP,sprev,cprev)
      # return statePred
      outputPred=self.decoderModule.outputLayer(statePred)
      # return outputPred, statePred
      _,maxIdx=outputPred.topk(1)
      sprev=scurr
      cprev=ccurr
      decoderIP=self.TeluguEmbedding(maxIdx[:,0])
      if batchIP:
        batchSize,_,vocabSize=outputPred.size()
        outputSeq.append(outputPred.view(batchSize,vocabSize))
      else:
        _,vocabSize=outputPred.size()
        outputSeq.append(outputPred.view(vocabSize))

    firstCharPred=torch.zeros(outputPred.size())

    if batchIP:
      firstCharIndex=targetSeq[0][0]
      firstCharPred[...,firstCharIndex]=1
      batchSize,_,vocabSize=firstCharPred.size()
      outputSeq.insert(0,firstCharPred.view(batchSize,vocabSize))
      outputSeq=torch.stack(outputSeq,dim=1)
    else:
      firstCharIndex=targetSeq[0]
      firstCharPred[...,firstCharIndex]=1
      _,vocabSize=firstCharPred.size()
      outputSeq.insert(0,firstCharPred.view(vocabSize))
      outputSeq=torch.stack(outputSeq,dim=0)

    outputProbs=torch.nn.functional.softmax(outputSeq,dim=-1)
    # outputProbs=torch.cat((firstCharPred,outputProbs),dim=-2)

    return outputProbs

# %%
myModelFinal=EncDecModel(myConfig)
myModelFinal.load_state_dict(torch.load('latest_model.model',map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
numEpochs=15
learningRate=0.001
optimizer=torch.optim.Adam(myModelFinal.parameters(),learningRate)

# %%
criterion=nn.CrossEntropyLoss()
myModelFinal.train()
minLoss=4
for epoch in range(1,numEpochs+1):
  print('epoch is.........',epoch)
  totalLoss=0.0
  count=0
  numBatches=len(trainDL)
  for inputSeq,targetSeq in trainDL:
    optimizer.zero_grad()
    outputProbs=myModelFinal(inputSeq,targetSeq)
    loss=criterion(outputProbs.view(-1,outputProbs.size(-1)),targetSeq.type(torch.long).view(-1))
    loss.backward()
    optimizer.step()
    totalLoss+=loss.item()
    if count%80 == 0:
      print('completed: ',100*count/numBatches)
    count+=1
  trainLoss=totalLoss/numBatches
  if trainLoss<minLoss:
    minLoss=trainLoss
    print('saving model...')
    torch.save(myModelFinal.state_dict(), "latest_model.model")
    torch.save(optimizer.state_dict(), "latest_optim.model")
  print(f"Epoch {epoch}/{numEpochs} | Train Loss: {trainLoss:.4f}")
# Out:
# epoch is......... 1
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 1/15 | Train Loss: 3.5522
# epoch is......... 2
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 2/15 | Train Loss: 3.4777
# epoch is......... 3
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 3/15 | Train Loss: 3.4510
# epoch is......... 4
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 4/15 | Train Loss: 3.4352
# epoch is......... 5
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 5/15 | Train Loss: 3.4184
# epoch is......... 6
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 6/15 | Train Loss: 3.4125
# epoch is......... 7
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 7/15 | Train Loss: 3.4085
# epoch is......... 8
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 8/15 | Train Loss: 3.4039
# epoch is......... 9
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 9/15 | Train Loss: 3.3924
# epoch is......... 10
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 10/15 | Train Loss: 3.3823
# epoch is......... 11
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 11/15 | Train Loss: 3.3774
# epoch is......... 12
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 12/15 | Train Loss: 3.3752
# epoch is......... 13
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 13/15 | Train Loss: 3.3685
# epoch is......... 14
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 14/15 | Train Loss: 3.3577
# epoch is......... 15
# completed:  0.0
# completed:  10.0
# completed:  20.0
# completed:  30.0
# completed:  40.0
# completed:  50.0
# completed:  60.0
# completed:  70.0
# completed:  80.0
# completed:  90.0
# saving model...
# Epoch 15/15 | Train Loss: 3.3543

# %%
myModelFinal=EncDecModel(myConfig)
myModelFinal.load_state_dict(torch.load('latest_model.model',map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
def getWord(indices,charDict,startChar,endChar,paddingChar):
 word=""
 for i in indices:
  j=i.item()
  # word+=charDict[j]
  if charDict[j]==endChar:
    break
  elif not(charDict[j]==startChar or charDict[j]==paddingChar):
    word+=charDict[j]
 return word

# %%
myModelFinal.eval()
predTeluguString=[]
N=len(testDS)
count=0
teluguWordActualIdxList=torch.stack(testYIndex,dim=0).type(torch.long)
teluguWordPredIdxList=[]
words=[]
for latinWordIdx, teluguWordIdx in testDS:
  teluguWordPredProbs=myModelFinal(latinWordIdx,teluguWordIdx)
  _,maxIdx=teluguWordPredProbs.topk(1)
  teluguWordPredIdx=maxIdx.view(-1)

  latinWord=getWord(latinWordIdx,charInvDictX,startChar,endChar,paddingChar)
  teluguWord=getWord(teluguWordIdx,charInvDictY,startChar,endChar,paddingChar)
  teluguWordPred=getWord(teluguWordPredIdx,charInvDictY,startChar,endChar,paddingChar)

  predTeluguString.append(teluguWordPred)
  words.append([latinWord,teluguWord,teluguWordPred])
  print(latinWord,',',teluguWord,',',teluguWordPred)
  # if count==100:
  #   break
  if count%128 ==0:
    print('completed: ',100*count/N)
  count+=1
  teluguWordPredIdxList.append(teluguWordPredIdx)

teluguWordPredIdxList=torch.stack(teluguWordPredIdxList,dim=0)
test_df_disp['prediction']=predTeluguString
accuracy=(teluguWordPredIdxList==teluguWordActualIdxList).all(axis=1).sum().item()/N


df=pd.DataFrame(words,columns=['Source','Target','Predicted'])
df.to_csv('Test_predictions_Vanilla.csv',index=False)
# Out:
# vithananni , విత్తనాన్ని , వితాన్ని
# completed:  0.0
# prayaanikulu , ప్రయాణికులు , ప్రాానికులు
# hassan , హసన్ , కస్సన్
# pakshala , పక్షాల , పక్షల
# goutham , గౌతమ్ , జోతం
# puraanamulanu , పురాణములను , పురానములను
# annintinii , అన్నింటినీ , ఆన్నితనిని
# uttarakoriyaa , ఉత్తరకొరియా , జత్తరకోరిిా
# vondala , వొందల , వోదదల
# yedhurkonendhuku , ఎదుర్కొనేందుకు , ్ేదుర్కోనేదదుకు
# digudu , దిగుడు , దిదుదు
# lancaster , లన్కాస్టర్ , లాన్సా్్్్్
# undo , ఉందో , బుదో
# yemmiganur , ఎమ్మిగనూర్ , పేమ్మిననరర్
# poll , పోల్ , పోల్ల
# saiqil , సైకిల్ , సాకిల్
# sanoop , సనూప్ , సనోర్
# freeman , ఫ్రీమ్యాన్ , క్రేమన్
# chaddi , చద్ది , చద్ది
# gurnani , గుర్ణని , జుర్ననని
# akolkar , అకోల్కర్ , ఆకోల్రర్
# gilmore , గిల్మోర్ , జిల్మోర్
# teesenduku , తీసేందుకు , తేసేనదుకు
# manasulone , మనసులోనే , మనసులోనే
# kadhalugaa , కధలుగా , కాలుుా
# prachaaraamsham , ప్రచారాంశం , ప్రచారాాసం
# whistle , విజిల్ , విస్త్లే
# prateecharyalo , ప్రతీచర్యలో , ప్రతరచర్్లో
# saanukoolata , సానుకూలత , సానుకోలత
# aerpadaka , ఏర్పడక , ఆర్రదక
# syracuse , సైరక్యూస్ , స్రరకుస్
# rasindi , రాసింది , రాసిదది
# saralatha , సరళత , సరలత
# boksing , బాక్సింగ్ , బోక్సి్్్
# vydyamlo , వైద్యంలో , వ్దేదరలలో
# oraacle , ఒరాకిల్ , ఆరాక్లే
# chha , ఛ , చ్
# aemaathram , ఏమాత్రం , ఆమాత్రం
# sabhalloo , సభల్లో , సాల్లో
# costa , కోస్తా , కోస్క
# varninchukuntunnaaru , వర్ణించుకుంటున్నారు , వర్నికచుకుుుున్నారు
# fluuid , ఫ్లూయిడ్ , క్లుది
# cheppay , చెప్పే , చేక్వం
# daaktarugaa , డాక్టరుగా , దాక్తరుుా
# ghatane , ఘటనే , బతనే
# raallapalli , రాళ్ళపల్లి , రాల్లలల్లి
# poosi , పూసి , పోసి
# bhatnagar , భట్నాగర్ , బత్నాార్
# kalugadu , కలుగదు , కలుుాుు
# parishkarinchenduku , పరిష్కరించేందుకు , పరిష్కరికచేేదుకు
# vijayamu , విజయము , వికాము
# charithrakaarula , చరిత్రకారుల , చరిత్రకారుల
# podhupunu , పొదుపును , పోదుకును
# azhar , అజహర్ , ఆకార్
# natistuunee , నటిస్తూనే , నాిస్తునే
# coimbatore , కోయంబత్తూర్ , కామిమాోోర్
# rudraa , రుద్రా , రుద్దా
# sanchaara , సంచార , సాచార
# sofhiya , సోఫియా , సోకిచా
# sareeramlooki , శరీరంలోకి , సరరరరలోకి
# mandalini , మండలిని , మదదలిని
# ketkhup , కెచప్ , కేత్కుర్
# kachheri , కచ్చేరీ , కచ్చేరి
# dheepaala , దీపాల , దేకాల
# paibhaagaanni , పైభాగాన్ని , పికాకాన్ని
# tallidandrulato , తల్లిదండ్రులతో , తల్దిదదద్రులతో
# shoes , షూస్ , సోక్
# shaw , షా , సావ్
# kaamredlu , కామ్రేడ్లు , కామ్రర్్లు
# keerti , కీర్తి , కేర్తి
# rane , రానే , రానే
# cheppinatlugaa , చెప్పినట్లుగా , చేమ్నినన్లుుా
# pravesinche , ప్రవేశించే , ప్రవేసికచే
# godhumalanu , గోధుమలను , జోదుమలను
# daman , డామన్ , దామన్
# thalapimchey , తలపించే , తలదిచచచే
# hydrocarba , హైడ్రోకార్బ , ీి్్రోకార్్
# vitthanam , విత్తనం , విత్తనం
# theesukookundaa , తీసుకోకుండా , తేసుకోకుుదా
# sind , సింద్ , సిదద్
# kalraa , కలరా , కల్రా
# gosangi , గోసంగి , జోసాకి
# sheershikaku , శీర్షికకు , సేర్షికకు
# teelchadam , తేల్చడం , తేల్చదం
# betul , బెటుల్ , బ్తుల్
# dibrugarh , డిబ్రూగర్ , దిర్రురా్్
# kochi , కొచ్చి , కోచ్చి
# heal , హీల్ , రిలల్
# watson , వాట్సన్ , వాత్సన్్
# naayaku , నాయకు , నాకకు
# todella , తోడేళ్ళ , తోదేల్ల
# washington , వాషింగ్టన్ , వాషిక్్్నన్
# waagwaadaaniki , వాగ్వాదానికి , వాక్దాదానికి
# completed:  9.375
# urdulo , ఉర్దూలో , బర్దులో
# asthramulu , అస్త్రములు , ఆస్త్రములు
# poshinchaannaaru , పోషించాన్నారు , పోషికచాన్నారు
# khandinchi , ఖండించి , కాదినచి
# divyamyna , దివ్యమైన , దివ్వమన్న
# pramanamulu , ప్రమాణములు , ప్రమనములు
# jaipur , జైపూర్ , జారరర్
# paeda , పేడ , పాదా
# kashtamie , కష్టమై , కష్తామి
# cheppalani , చెప్పాలని , చేక్రలని
# rendintalu , రెండింతలు , రేనదికతలు
# terapaina , తెరపైన , తేరాాన
# andamunu , అందమును , ఆదదమును
# muulikaa , మూలికా , ములికా
# portillo , పోర్టిల్లో , పోర్తిల్లో
# telchindi , తేల్చింది , తేల్చిదది
# melin , మేలిన్ , మిలిన్
# moradabad , మొరాదాబాద్ , మోరాాా్్
# amer , అమీర్ , ఆమేర్
# vyavaharistondani , వ్యవహరిస్తోందని , వ్వవరరిస్తోోదని
# phaaloo , ఫాలో , పాలో
# niraakarinchataanni , నిరాకరించటాన్ని , నిరాకరిచచాాన్ని
# pandagaa , పండగా , పాదతా
# jarnalistulanu , జర్నలిస్టులను , జర్నలిస్తులను
# sijanlo , సీజన్లో , సినన్లో
# praarambhinchaaranna , ప్రారంభించారన్న , ప్రారామిిచారన్న
# hassan , హాసన్ , కస్సన్
# ganibavinchi , ఘనీభవించి , కనికవిిచి
# bathroomloni , బాత్రూంలోని , బత్రోోలోని
# sarvasabhya , సర్వసభ్య , సర్వసస్్
# laen , లేన్ , లాన్న్
# maddox , మ్యడ్డాక్స్ , మద్కో్్
# vestunnaarenti , వేస్తున్నారేంటి , వేస్తున్నారన్తి
# paasta , పాస్తా , పాస్త
# taaraabaasov , తారాబాసోవ్ , తారాకాసోవ్
# phalitaalato , ఫలితాలతో , పలితాలతో
# shmashanavatika , శ్మశానవాటిక , స్మాననవిిక
# rajahmundry , రాజమండ్రి , రాకక్ముు్్ి
# yerpadenduku , ఏర్పడేందుకు , ్ర్రదేేదదకు
# paalpadindi , పాల్పడింది , పాల్లదిిది
# vintuu , వింటూ , వితతు
# paruvupoyi , పరువుపోయి , పరువుకోోి
# inc , ఇంక్ , పన్్
# piji , పిజి , పికి
# rockford , రాక్ఫోర్డ్ , రాక్కోర్్్
# mayuuram , మయూరం , మాురరం
# agnipramaadam , అగ్నిప్రమాదం , ఆన్నిర్రమాదం
# adhyayanamu , అధ్యయనము , ఆద్దానము
# dopidiki , దోపిడీకి , దోమిదికి
# chanakya , చాణక్య , చనక్్
# utthamamgaa , ఉత్తమంగా , ఆత్తమమకా
# viswasaniiyamgaa , విశ్వసనీయంగా , విస్వసనిినాా
# dongala , దొంగలా , దోనకల
# devalayam , దేవాలయం , దేవాలంం
# dhadito , దాడితో , దదితో
# miller , మిల్లెర్ , మిల్లర్
# kunuku , కునుకు , కుకుకు
# geraald , గెరాల్డ్ , జిరాల్ద్
# marche , మార్చే , మార్చే
# innayya , ఇన్నయ్య , పన్నా్్
# undho , ఉందో , బదదో
# unnadi , ఉన్నది , బన్నది
# muulikala , మూలికల , ములికల
# dopidee , దోపిడీ , దోదిదే
# saralata , సరళత , సరలత
# bhatt , భట్ , బా్్్
# yamakinkarulu , యమకింకరులు , పమమిికరులు
# vishwaasaalanu , విశ్వాసాలను , విష్వాసాలను
# impugaa , ఇంపుగా , జమదుకా
# cheppukonnappatiki , చెప్పుకొన్నప్పటికీ , చేక్కుకోన్నన్్రికి
# bengaluru , బెంగళూరు , బేనమలురు
# dayton , డేటన్ , దాతనన్
# mudadugula , మూడడుగుల , ముదదుుుల
# vilekharulato , విలేఖరులతో , విలేకరులతో
# raaninchaadu , రాణించాడు , రానికచాదు
# ochoa , ఒచోవా , ఆచో
# kakeseeaar , కకేసీఆర్ , కాేసేార్్
# september , సెప్టెంబర్ , సకక్తరరరర్
# hastal , హాస్టల్ , కస్తాల్
# divaan , దివాన్ , దివాన్
# gutti , గుట్టి , జుత్తి
# panchakamu , పంచకము , పాచకము
# berlin , బెర్లిన్ , బరర్లిన్
# sangli , సంగ్లీ , సాక్లి
# holidays , హాలిడేస్ , లోలిదాస్
# dahlan , డహ్లాన్ , దా్లన్
# len , లేన్ , లిన్
# dhvaninche , ధ్వనించే , ద్వనినచే
# nerasthulaku , నేరస్థులకు , నేరస్తులకు
# vinaayakudu , వినాయకుడి , వినాకకుదు
# gaayanii , గాయనీ , జాాని
# chotulo , చోటులో , చోతులో
# sanghaaniki , సంఘానికి , సాదానికి
# chaeyunu , చేయును , చేకును
# gurtinchadagga , గుర్తించదగ్గ , కుర్తికచదద్్
# flynn , ఫ్లిన్ , క్లాన్
# raajadhaanulu , రాజధానులు , రాకకానులు
# pasco , పాస్కో , పాస్కో
# eeloogaa , ఈలోగా , ఆలోకా
# nersthulanu , నేరస్థులను , నేర్స్తులను
# diviteeni , దివిటీని , దివితేని
# vaishnavi , వైష్ణవి , విష్నవి
# wockhardt , వోకార్డ్ట్ , వాక్చార్్్్్
# kaali , కాళీ , కాలి
# tadanamtara , తదనంతర , తదనతతరర
# balmiki , బాల్మీకి , బాల్మికి
# dial , డయల్ , దికాల్
# rasamayi , రసమయి , రసమమి
# fayetteville , ఫయెట్విల్లే , కాాత్్్విల్లే
# satyagraham , సత్యాగ్రహం , సత్్రర్రం
# graham , గ్రహం , జ్రాం
# range , రేంజ్ , రానే
# dheshi , దేశి , దేషి
# joliet , జోలియెట్ , జోలిక్్
# ankelanu , అంకెలను , ఆనకేలను
# telipe , తెలిపే , తేలికే
# brahmaandamiena , బ్రహ్మాండమైన , బ్రక్మాదమమిిన
# sugar , షుగర్ , సురార్
# guruthva , గురుత్వ , బురుత్వ
# pampabadutundi , పంపబడుతుంది , పాదాదుతుుది
# abhyunnatiki , అభ్యున్నతికి , ఆక్నున్నతికి
# vinyasaaniki , విన్యాసానికి , విన్నసానికి
# prakatistaamani , ప్రకటిస్తామని , ప్రకతిస్తామని
# sareeramloki , శరీరంలోకి , సరరరలలోకి
# gottaanni , గొట్టాన్ని , జోత్తాన్ని
# disa , దిశా , దిసా
# yelina , ఏలిన , జేలిన
# guntur , గుంటూరు , జు్తుర్
# pundu , పుండు , పుదదు
# toeluku , తోలుకు , తోలుకు
# aazaad , ఆజాద్ , ఆరాద్
# parvam , పర్వం , పర్వం
# avanni , అవన్నీ , ఆవన్ని
# aktivity , ఆక్టివిటీ , ఆక్తివివి
# tinley , టిన్లి , తిన్లే
# supreemkortulo , సుప్రీంకోర్టులో , సుర్రురరోక్తులో
# nagraj , నాగరాజ్ , నా్రాా్్
# vidhvamsudu , విద్వాంసుడు , విక్వాసుుు
# stetes , స్టేట్స్ , స్తేత్స్
# sweekarinchinappudu , స్వీకరించినప్పుడు , స్వేకరిిచినన్్ుుు
# parishkarinchalekapoyaarane , పరిష్కరించలేకపోయారనే , పరిష్కరికచలేకకోోారనే
# baaksaaphisu , బాక్సాఫీసు , బాక్కాసిషు
# pottato , పొట్టతో , పోత్తతో
# mandipokundaa , మండిపోకుండా , మాదికోకుదదా
# vishwakarma , విశ్వకర్మ , విష్వకర్మ
# yaajamaanyaanni , యాజమాన్యాన్ని , పామమాన్నాన్ని
# jaagu , జాగు , జారు
# vasoollandukunna , వసూళ్లందుకున్న , వసోక్లనదదుకున్న
# journalistoo , జర్నలిస్టూ , జోర్నలిస్తో
# charchinchindi , చర్చించింది , చర్చికచిిది
# marlborough , మార్ల్బరో , మార్లోరోర్
# manugadaku , మనుగడకు , మనుుదకు
# jatilamaina , జటిలమైన , జతిలమమన
# gulf , గల్ఫ్ , జుల్
# kashta , కష్ట , కష్త
# ennosaarlu , ఎన్నోసార్లు , ్న్నోసార్లు
# gundamu , గుండము , కుదదము
# konnitiki , కొన్నిటికి , కోన్నితికి
# badmeenton , బ్యాడ్మింటన్ , బా్మామననన్
# inpugaa , ఇంపుగా , జన్నుుా
# toluku , తోలుకు , తోలుకు
# saalaakhaddoos , సాలాఖద్దూస్ , సాలాదద్దోస్
# randall , రందల్ , రాదల్ల
# tisukochhinattayindi , తీసుకొచ్చినట్టయింది , తిసుకోచ్చికచ్చిిదది
# suryanarayana , సూర్యనారాయణ , సుర్నాారాాన
# plantation , ప్లాంటేషన్ , ప్లాతాతనన్
# pakshaniki , పక్షానికి , పక్షనిిి
# sanniveesha , సన్నివేశ , సన్నివేస
# puyallup , పూయల్లుప్ , పునాల్లు
# khaidila , ఖైదీల , కిదిల
# vantakaalu , వంటకాలు , వాతకాలు
# taralistunna , తరలిస్తున్న , తరలిస్తున్న
# saran , సరాన్ , సరాన్
# ikeji , ఇకెజి , పకేరి
# vayuvula , వాయువుల , వాుువుల
# kolukoleni , కోలుకోలేని , కోలుకోలేని
# baahubalini , బాహుబలిని , బారులలిని
# baagugaa , బాగుగా , బాకుకా
# vandutharu , వండుతారు , వాదుతారు
# hillsboro , హిల్స్బోరో , పిల్క్స్లో
# cover , కవర్ , కోవర్
# apakeerthi , అపకీర్తి , ఆకకరర్తి
# wolf , వోల్ఫ్ , వోల్న్
# pakshaaniki , పక్షానికి , పక్షానికి
# murti , మూర్తి , ముర్తి
# teesukuvastunnaadani , తీసుకువస్తున్నాడని , తేసుకువస్తున్నానని
# merta , మేర్త , మిర్త
# seamec , సీమెక్ , సిమేే్
# subex , సుబెక్స్ , సు్క్్్
# pali , పాలీ , పాలి
# saanghika , సాంఘిక , సాకకిక
# dikk , డిక్ , దిక్క
# mrutadehaalu , మృతదేహాలు , ముతదేదాలు
# plainfield , ప్లైన్ఫీల్డ్ , ప్లిన్నిల్్
# mosley , మాస్లీ , మోస్లే
# kglu , కేజీలు , క్ర్లు
# kashtapaddaayi , కష్టపడ్డాయి , కష్షదద్నాది
# toliprema , తొలిప్రేమ , తోలిర్రేమా
# zoin , జాయిన్ , జోనిన్
# thattukune , తట్టుకునే , తత్తుకునే
# siggupadutunnattuga , సిగ్గుపడుతున్నట్టుగా , సిద్దుదదుతున్నద్ుుుా
# yasukaa , యసుకా , కసుకా
# vaagu , వాగు , వాకు
# fungal , ఫంగల్ , ్ురవల్
# ruber , రబ్బర్ , రుకర్
# gowtam , గౌతమ్ , జోవతం
# hrudayamlo , హృదయంలో , రుదాాలో
# anvayinchevaaru , అన్వయించేవారు , ఆన్వాిిచేవారు
# rutuvulo , ఋతువులో , రుతువులో
# tootaalu , తూటాలు , తోతాలు
# thomas , థామస్ , తోమాస్
# ethadu , ఈతడు , ేతదు
# vaemula , వేముల , వాముల
# saritha , సరిత , సరిత
# bodhistundi , బోధిస్తుంది , బోదిస్తుదది
# moody , మూడీ , మోద్
# mountain , మౌంటెయిన్ , ముకతాన్
# asthvyastham , అస్తవ్యస్తం , ఆస్త్వ్వస్తం
# taragaalanu , తరంగాలను , తరతాలను
# ballapie , బల్లపై , బల్లారా
# praathipadhikagaa , ప్రాతిపదికగా , ప్రాతికకిికా
# bite , బైట్ , బితే
# ravuto , రావుతో , రావుతో
# phederation , ఫెడరేషన్ , పేదరరతనన్
# valasi , వలసి , వలసి
# estes , ఎస్టెస్ , ్స్తేస్
# amaayaka , అమాయక , ఆమాకక
# charchinchadaaniki , చర్చించడానికి , చర్చికచదానికి
# customs , కస్టమ్స్ , కస్స్్ో్
# mangla , మంగ్లా , మాక్ల
# kover , కవర్ , కోవర్
# aandhrasarasvati , ఆంధ్రసరస్వతి , ఆనద్రససస్వవి
# benitez , బెనిటెజ్ , బినిత్న్
# gagan , గగన్ , జాాన్
# junction , జంక్షన్ , జు్క్నన్
# completed:  31.25
# unnaarantae , ఉన్నారంటే , బన్నారుతే
# marchalani , మార్చాలని , మార్చాని
# evadiete , ఎవడైతే , బవదితతే
# darsi , దర్శి , దర్సి
# pradarshinchetatuvanti , ప్రదర్శించేటటువంటి , ప్రదర్షిచచే్తుువతి
# waatchmen , వాచ్మెన్ , వాచ్చ్మ్మన్
# careerlone , కెరీర్లోనే , కారర్్లోన్
# raajamandrini , రాజమండ్రిని , రామమాద్రిని
# azeez , అజీజ్ , ఆకేర్
# eagan , ఎగన్ , ్రన్
# gurtunnanu , గుర్తున్నాను , కుర్తున్నాను
# prajalloki , ప్రజల్లోకి , ప్రాల్లోకి
# vyaakhyalato , వ్యాఖ్యలతో , వ్కాక్షలతో
# teeyamani , తీయమని , తేకమని
# dveepanni , ద్వీపాన్ని , ద్వేనన్ని
# dvepanni , ద్వీపాన్ని , ద్వేనాన్ని
# mandulanu , మందులను , మదదులను
# pampinchandi , పంపించండి , పాకిిచకది
# malayalee , మలయాళ , మలాాలే
# vibhudhi , విభూది , విదుది
# praveshinchenduku , ప్రవేశించేందుకు , ప్రవేవిచచేదదుకు
# gelipisthey , గెలిపిస్తే , జేలికిస్తే
# raalekapoyinatlu , రాలేకపోయినట్లు , రాలేకకోోినన్లు
# viraalaalu , విరాళాలు , విరాలాలు
# raman , రామన్ , రామన్
# dearborn , డియర్బార్న్ , దిరారరర్న్
# icchaapuram , ఇచ్ఛాపురం , పచ్చారురం
# panjaab , పంజాబ్ , పానార్
# pereddy , పెరెడ్డి , పేరేద్రి
# varma , వర్మ , వర్మ
# rajkot , రాజ్కోట్ , రాక్ోో్్
# gangtok , గ్యాంగ్టోక్ , బానా్ోో్్
# raayitho , రాయితో , రాిితో
# siel , సీల్ , సిలల్
# redmond , రెడ్మొండ్ , రిమ్మో్్
# shores , షోరేస్ , సోర్స్
# maggutunna , మగ్గుతున్న , మక్రుతున్న
# naatadam , నాటడం , నాతదం
# dundagulu , దుండగులు , దుదదుులు
# chendhadamtoo , చెందడంతో , చేనదదాతో
# paryavekshinchaaru , పర్యవేక్షించారు , పర్్వకక్షిచచారు
# varanasi , వారణాసి , వరరసి
# pooshinchinadi , పోషించినది , పోషిిచినది
# theejasvini , తేజస్విని , తేసవ్విని
# yaantrikamiena , యాంత్రికమైన , జాకత్రికమిిన
# anuvadistunnadi , అనువదిస్తున్నది , ఆనువదిస్తున్నది
# kutra , కుట్ర , కుర్ర
# avabhruda , అవభృద , ఆవర్రు
# istunnaamani , ఇస్తున్నామని , ్స్తున్నామని
# dheshaabhivruddhiki , దేశాభివృద్ధికి , దేవారివ్ద్దికి
# bhujampai , భుజంపై , బురాదే
# nowgong , నౌగొంగ్ , నోమోన్్్
# kareres , కరేరేస్ , కారరర్స్
# cerebra , సెరెబ్రా , సేర్ర్ర్
# dhivyamaina , దివ్యమైన , దివ్ేమమన
# mandalamu , మండలము , మదదలము
# draupathi , ద్రౌపతి , ద్రాుతి
# pottakooti , పొట్టకూటి , పోత్తకోతి
# brownsville , బ్రౌన్స్విల్లే , బ్రోన్స్విల్లే
# kamaneeyamga , కమనీయంగా , కమనేేేదా
# santa , శాంటా , సాత
# dhaanyam , ధాన్యం , దాన్్ం
# ink , ఇంక్ , పనక్
# lynchburg , లించ్బర్గ్ , ల్ల్నకర్్్
# thaalib , తాలిబ్ , తాలిన్
# fleming , ఫ్లెమింగ్ , క్లిమి్్
# bindal , బిండల్ , బినదల్
# shmashaanavaatika , శ్మశానవాటిక , స్రాానావతిక
# rasheed , రషీద్ , రషేద్
# thaagimdi , తాగింది , తాకిదది
# seattle , సియటెల్ , సాక్త్లే
# khaidi , ఖైదీ , కిది
# panchatantra , పంచతంత్ర , పాచనాత్ర
# kirthini , కీర్తిని , కిర్తిని
# vidvaansudu , విద్వాంసుడు , విద్వాన్సుుు
# chendadamtho , చెందడంతో , చేనదదాతో
# centennial , సెంటేనియల్ , సానననన్న్లల్
# agarawal , అగర్వాల్ , ఆమరాావ్
# whittier , వైట్టియర్ , విత్తిరర్
# priya , ప్రియ , ప్రిక
# alayalu , ఆలయాలు , ఆలాాలు
# priyadarshini , ప్రియదర్శిని , ప్రిిదర్్ిని
# zanet , జానెట్ , జనన్్
# indianapolis , ఇండియానాపోలిస్ , బనదిననికోలివ్
# anivaaryamgaa , అనివార్యంగా , ఆనివార్రమాా
# agency , ఏజన్సీ , ఆకాన్్ి
# prakatanalanu , ప్రకటనలను , ప్రకతనలను
# mahapanditudu , మహాపండితుడు , మాాదాదితుుు
# laeraa , లేరా , లేరా
# hajipur , హజిపుర్ , మాిిిరర్
# daantopaatu , దాంతోపాటు , దాతతోోాతు
# ganistharu , గణిస్తారు , కనిస్తారు
# merlinch , మెర్లించ్ , మరర్లిచచ్
# naadir , నాదిర్ , నాదిర్
# bodhimchindi , బోధించింది , బోదిిచిిది
# aalayyalu , ఆలయాలు , ఆలక్్లలు
# juarez , జ్వారెజ్ , జురరర్న్
# khatri , ఖత్రి , కర్్ి
# pittsburgh , పిట్స్బర్గ్ , పిత్స్స్ర్్్్
# mogistunnaamani , మోగిస్తున్నామని , మోమిస్తున్నామని
# le , లే , లేల్
# kotturu , కొత్తూరు , కోత్తురు
# jeyuduyurugaata , జేయుదురుగాత , జేదుదురుదురాత
# karbonetlu , కార్బోనేటులు , కార్కోనేల్లు
# coachella , కోచెల్లా , కోచచల్ల
# mooseeki , మూసీకి , మోసేకి
# opikagaa , ఓపికగా , ఆకికకా
# jauhari , జౌహరి , జారారి
# kettering , కెట్టెరింగ్ , కిత్తరరిక్
# mandhugaa , మందుగా , మాదుకా
# togooru , తోగూరు , తోరోరు
# moreno , మోరెనో , మోరేనో
# jaat , జాట్ , జాత్
# keizer , కైజర్ , కేత్ర్
# mayur , మయూర్ , మాాుర్
# spandinchaadu , స్పందించాడు , స్దాదినచాదు
# maroka , మరోక , మరోక
# mundhumaatalo , ముందుమాటలో , మునుుమాతలో
# kuuragayalanu , కూరగాయలను , కురాాాలను
# yuvatanu , యువతను , దువతను
# praarambhinchandi , ప్రారంభించండి , ప్రారాదిచచకది
# saralamga , సరళంగా , సరరలదా
# nootilo , నూతిలో , నోతిలో
# mahajan , మహాజన్ , మాాాన్
# baajee , బాజీ , బామే
# puttabotunnadanatu , పుట్టబోతున్నాడంటూ , పుత్తకోతోన్నదనను
# renewables , రెన్వేబుల్స్ , రినివాల్ల్
# yuvatha , యువత , దువత
# completed:  34.375
# vijayaalatho , విజయాలతో , వికాాలతో
# starayid , స్టెరాయిడ్ , స్తారాిి్్
# bedford , బెడ్ఫోర్డ్ , బాద్రోర్
# nirvahinchalekapotondi , నిర్వహించలేకపోతోంది , నిర్వవిచచలేకకోతోోది
# bedhirinattugaa , బెదిరినట్టుగా , బేదిరినన్రుుా
# park , పార్క్ , పార్క్
# cheppavacchu , చెప్పవచ్చు , చేక్వవచ్చు
# taagadaaniki , తాగడానికి , తాదదానికి
# rajyaniki , రాజ్యానికి , రా్్నానికి
# varnamaala , వర్ణమాల , వర్నమాల
# kavarla , కవర్ల , కవర్ల
# vyaktule , వ్యక్తులే , వ్కక్తులే
# patishthamaina , పటిష్ఠమైన , పతిష్కమనన
# controls , కంట్రోల్స్ , కాో్్రల్్్
# roganni , రోగాన్ని , రోనా్నన
# vaayuvula , వాయువుల , వాదువుల
# bomma , బొమ్మ , బోమ్మ
# vaartathoo , వార్తతో , వార్తతో
# bhadauriya , భదౌరియా , బదరుిి
# hodges , హోడ్జ్స్ , ఆోద్క్స్
# lepinchaadu , లేపించాడు , లేనినచాదు
# bhagaswamulaku , భాగస్వాములకు , బాసస్వాములు
# cheppalekapoyaaru , చెప్పలేకపోయారు , చేక్రలేకకోోారు
# cheyuchu , చేయుచు , చేకుచు
# miramar , మిఱమాఱ్ , మిరామర్
# vaasudhevaraavu , వాసుదేవరావు , వాసుకవవరావు
# dharanu , ధరను , దరాను
# kaastunnattundi , కాస్తున్నట్టుంది , కాస్తున్నద్రుుది
# ganapathy , గణపతి , బననత్
# raangaguvaa , రాంగగువా , రాకరరువా
# ketuvaa , కేతువా , కేతువా
# uuhaatmaka , ఊహాత్మక , ఆకాత్మక
# praadhamikamgaa , ప్రాథమికంగా , ప్రామమికకకా
# bayatapadalekapotunnaarani , బయటపడలేకపోతున్నారని , బాతకదలేతతోోున్నారని
# podupunu , పొదుపును , పోదుకును
# reportainaa , రిపోర్టయినా , రిరోర్తేనా
# khaideela , ఖైదీల , కిదాల
# ...
# tejaswini , తేజస్విని , తేకస్విని
# nipunudu , నిపుణుడు , నినునుదు
# suukti , సూక్తి , సుక్తి
# upayoginchani , ఉపయోగించని , బుకోదిిచని
# challagaane , చల్లగానే , చల్లకానే
# raayigaa , రాయిగా , రాిికా
# ardhamtoe , అర్థంతో , ఆర్దేతో
# rekethisthai , రేకెత్తిస్తాయి , రికేతిస్తి
# yatha , యథా , దత
# velthundaga , వెళ్తుండగా , వేల్తునదాా
# vyavaharistunnaadani , వ్యవహరిస్తున్నాడని , వ్వవరరిస్తున్నానని
# ramayanamlo , రామాయణంలో , రామాానలో
# kottukunee , కొట్టుకునే , కోత్తుకునే
# chandernagore , చండెర్ణగొరే , చాదర్్రరోర్
# kalagajesukontaarani , కలుగజేసుకొంటారని , కలేకకసుకోతలారని
# chesukolekapotunnaadu , చేసుకోలేకపోతున్నాడు , చేసుకోలేకతోతున్నాాు
# education , ఎడ్యుకేషన్ , ్దుకతనన్
# vindhya , వింధ్య , విదద్
# inthaku , ఇంతకు , పనతకు
# vyoohaatmakangaa , వ్యూహాత్మకంగా , వ్కోతాత్మమోకా
# vimarshistunnaav , విమర్శిస్తున్నావ్ , విమర్షిస్తున్నావ్
# reddy , రెడ్డి , రిద్్ి
# uttar , ఉత్తర్ , ఆత్తర్
# chachhaaru , చచ్చారు , చచ్చారు
# satyamoorti , సత్యమూర్తి , సత్్మోర్తి
# prayaanhikulanu , ప్రయాణికులను , ప్రాానికులను
# mahaavishnuvu , మహావిష్ణువు , మరావిష్వువు
# vibhudi , విభూది , విదుది
# krishnanagar , కృష్ణానగర్ , కిష్షననార్్
# aaharamuloo , ఆహారములో , ఆరరములో
# yekkinchukuntunnatlu , ఎక్కించుకుంటున్నట్లు , పేక్కికచుకునకున్నా్లు
# kalyaanam , కల్యాణం , కల్లానం
# sulthanu , సుల్తాను , సుల్తను
# ishtaaniki , ఇష్టానికి , బష్కానికి
# yajamanulaku , యజమానులకు , దామనుులకు
# malayali , మలయాళ , మాలాలి
# veyinchalekapoyaarani , వేయించలేకపోయారని , వేనికచలేకకోరారని
# bristol , బ్రిస్టల్ , బ్రిస్తోల్
# namunalu , నమూనాలు , నమునలు
# paastaa , పాస్తా , పాస్తా
# pasadena , పాసదేనా , పసాేనన
# muncipal , మున్సిపల్ , మున్ిిలల్
# sugar , సుగర్ , సురార్
# septembar , సెప్టెంబర్ , సిక్తేరాార్
# chithraranga , చిత్రరంగ , చిత్రరరద
# completed:  93.75
# aadhikyamloe , ఆధిక్యంలో , ఆదిక్కమలో
# shivastava , షివాస్తవ , కివస్తావా
# mali , మాలి , మాలి
# vaidhyamlo , వైద్యంలో , విద్వాలో
# sagamlo , సగంలో , సామలో
# bhayamgaa , భయంగా , బాాదా
# rushini , ఋషిని , రుషిని
# tolaginchalekapotunnaayi , తొలగించలేకపోతున్నాయి , తోలకికచలేకోోతున్నాాి
# hydrocaarba , హైడ్రోకార్బ , ీ్్్రోకార్్
# ucchaarana , ఉచ్ఛారణ , ీచ్చారన
# sayreville , సేయర్విల్ , సాేరవిల్లే
# deeshaanni , దేశాన్ని , దేషాన్ని
# marsh , మార్ష్ , మర్ష్
# abhivruddhini , అభివృద్ధిని , ఆదివుద్దిని
# boodhinchindi , బోధించింది , బోదిిచిిది
# aavaataar , అవతార్ , ఆవాతార్
# railway , రైల్వే , రాల్వా
# chambers , ఛాంబర్స్ , చామరర్స్
# daanube , డానుబే , దానుకే
# kaals , కాల్స్ , కాల్స్
# drukkoonam , దృక్కోణం , ద్రుకోనం
# cottaata , కొట్టాట , కోత్తాత
# chinnadhigaa , చిన్నదిగా , చిన్నదిిా
# paramaatmane , పరమాత్మనే , పరమాత్మమే
# chelleliki , చెల్లెలికి , చేల్లేలికి
# edipinchinaa , ఏడిపించినా , ్దికినచినా
# vistarimpa , విస్తరింప , విస్తరరిక
# sellers , సెల్లెర్స్ , సలల్లర్స్
# sandhaana , సంధాన , సాదాన
# zinc , జింక్ , జిన్్
# dabur , డాబర్ , దారుర్
# nevemberu , నవంబరు , నేవేేరరరు
# narasimgaraavu , నరసింగరావు , నాసిిమరావు
# samskaaramunna , సంస్కారమున్న , సాస్కారమున్న
# etman , ఆత్మ , జత్మాన్
# godala , గోడల , జోదల
# gati , గతి , బాిి
# majesco , మజేస్కో , మాకేస్కో
# laab , ల్యాబ్ , లాల్
# alankarinchukunnaadu , అలంకరించుకున్నాడు , ఆలకకరిచచుకున్నాాు
# glass , గ్లాస్ , ర్లాస్స్
# rao , రావ్ , రాకా
# social , సోషల్ , సోకికలల్
# nistunnappudu , నిస్తున్నప్పుడు , నిస్తున్న్్ుుుు
# tustin , టుస్టిన్ , తక్సిన్
# mahaadevi , మహాదేవి , మాాదేవి
# thyaagam , త్యాగం , త్రాకం
# nirodhakata , నిరోధకత , నిరోదకత
# paristitilone , పరిస్తితిలోనే , పరిస్తిరిలోనే
# aatmatoo , ఆత్మతో , ఆత్మతో
# arjununi , అర్జునిని , ఆర్రునుని
# pettistunnaayi , పెట్టిస్తున్నాయి , పేత్తిస్తున్నాాి
# puttabotunnaadantu , పుట్టబోతున్నాడంటూ , పుత్తకోతోత్నానాను
# gulmarg , గుల్మర్గ్ , జుల్మార్్్
# bremerton , బ్రెమెర్టన్ , బ్రరమరర్నన్
# haj , హజ్ , రా్్
# bagundanukoni , బాగుందనుకొని , బాకురదనుకోని
# nielsen , నీల్సన్ , నిల్స్న్
# rajayyadu , రాజయ్యాడు , రాాా్్ాాు
# panihati , పానిహతి , పనిషాిి
# finley , ఫైన్లీ , మిన్లల
# equiti , ఈక్విటీ , ్వ్వితి
# soap , సోప్ , సోక్్
# colton , కాల్టన్ , కలల్నన్
# completed:  96.875
# nalumuulalaa , నలుమూలలా , నలుములలా
# maatrices , మాట్రిక్స్ , మాత్రికేస్
# suchi , సుచి , సుచి
# caritrakarulu , చరిత్రకారులు , కరిత్రరరులుు
# omaxe , ఒమాక్స్ , ్మే్ే
# soocheelu , సూచీలు , సోచేలు
# varghese , వర్గీస్ , వర్షేస్
# vimaanaashrayamlo , విమానాశ్రయంలో , విమానాక్రాాలో
# yedhuta , ఎదుట , దేదుత
# mattancheri , మట్టంచెర్రి , మత్తాచేరి
# ekeekarana , ఏకీకరణ , ్కకకరర
# haley , హలే , రలలే
# spashtamcheshaaru , స్పష్టంచేశారు , స్షష్కచేచాారు
# hajj , హజ్ , రార్్్
# sane , సేన్ , సనే
# padae , పదే , పదే
# pogidinchukoodaaniki , పొగిడించుకోడానికి , పోదిదిచచుకోనానికి
# marchipovaddu , మర్చిపోవద్దు , మర్చికోవద్దు
# modalupettaalsi , మొదలుపెట్టాల్సి , మోదలుకోత్కాల్సి
# arati , అరటి , ఆరాి
# prabhutvashaakhala , ప్రభుత్వశాఖల , ప్రతుత్వవాాల
# sanghika , సాంఘిక , సాదిక
# prayaninchabothunnaru , ప్రయాణించబోతున్నారు , ప్రాాిిచచోతున్నారు
# montebello , మోంటెబెల్లో , మానతోకేల్లో
# saucer , సాసర్ , సాకేర్
# alaka , అలక , ఆలాక
# kanugonadamlo , కనుగొనడంలో , కనుకోనదాలో
# rachanalathoo , రచనలతో , రచనలతో
# nigative , నెగటివ్ , నికతివే
# vuhistaaru , ఊహిస్తారు , వుకిస్తారు
# athmanu , ఆత్మను , ఆత్మను
# spokane , స్పోకెనే , స్కోకానే
# orvalekapotunnadi , ఓర్వలేకపోతున్నది , ఆర్వలేకోతోున్నది
# rakkallo , రకాల్లో , రక్కల్లో
# dodson , దొడ్సన్ , దోద్సన్
# kottestunnaaru , కొట్టేస్తున్నారు , కోత్తేస్తున్నారు
# mcguire , ముగ్వియర్ , మ్క్రిర్వ
# mandamaina , మందమైన , మదదమమన
# fluorine , ఫ్లోరిన్ , క్లురిన్
# maphia , మాఫియా , మాాికా
# toranto , టొరంటో , తోరాతో
# karyalayamloonae , కార్యాలయంలోనే , కా్్లలలలోననే
# chaibasa , చైబాస , చికాస
# adigoo , అదిగో , ఆదికో
# gainakaalajist , గైనకాలజిస్ట్ , పినకాలిిస్త్
# saasanasabhaa , శాసనసభా , సాసనసాాా
# podu , పోడు , పోదు
# chelaregipothunna , చెలరేగిపోతున్న , చేలరేరికోతున్న
# rallato , రాళ్ళతో , రా్లలతో
# bennett , బెన్నెట్ , బనన్న్్్్్
# rahasyaalanu , రహస్యాలను , రకస్మాలను
# paerlanu , పేర్లను , పరర్లను
# urdoolo , ఉర్దూలో , బర్దోలో
# jagtap , జగ్తప్ , జా్తా్్
# intiloo , ఇంటిలో , ీనతిలో
# leelavathi , లీలావతి , లేలవతి
# aapaduddhaaraka , ఆపదుద్ధారక , ఆదదుద్దారక
# sivasagar , శివసాగర్ , సివసాార్
# tahatahalaadinavaare , తహతహలాడినవారే , తకతాలాదినవారే
# sens , సెన్స్ , సాన్స్
# clouud , క్లౌడ్ , క్లో్్
# fields , ఫీల్డ్స్ , పిల్ల్స్
# pogadachoopaayi , పొడచూపాయి , పోదదచోోాాి
# kommalatoo , కొమ్మలతో , కోమ్మలతో
# kukie , కుకీ , కుకి
# mosaginchadam , మోసగించడం , మోసాిిచదం
# telamgaanha , తెలంగాణ , తేలారాన
# patel , పటేల్ , పాేలల్
# peda , పేడ , పేదా
